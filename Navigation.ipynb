# %% [markdown]
# # Navigation
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the first project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893).
#
# ### 1. Start the Environment
#
# We begin by importing some necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np
from Agent import Agent
from collections import deque
import torch
import matplotlib.pyplot as plt
from dqn import dqn

# %%
bananaPath = "C:\\Dev\\Udacity\\DeepRL\\Banana_Windows_x86_64\\Banana_Windows_x86_64\\"
fullfilename = bananaPath + "Banana.exe"
dq = dqn(fullfilename, 0)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %%
agent = Agent(state_size=dq.statesize, action_size=dq.actionsize, seed=0)

# %%
score = 0
trainscores = dq.train(agent)
# Out:
# Episode 100	Average Score: 1.69
# Episode 200	Average Score: 6.22
# Episode 300	Average Score: 9.41
# Episode 400	Average Score: 10.44
# Episode 500	Average Score: 12.97
# Episode 600	Average Score: 14.45
# Episode 700	Average Score: 14.00
# Episode 800	Average Score: 14.48
# Episode 859	Average Score: 15.00
# Environment solved in 759 episodes!	Average Score: 15.00

# %%
plt.plot(trainscores)
plt.show()

# %%
agent.qnetwork_local.load_state_dict(torch.load('checkpoint.pth'))
testscores = dq.test(agent,10)
# Out:
# Environment average score is: 16.70

# %%
print(testscores)
plt.plot(testscores)
plt.show()
# Out:
# [19.0, 13.0, 14.0, 16.0, 18.0, 17.0, 19.0, 17.0, 16.0, 18.0]
